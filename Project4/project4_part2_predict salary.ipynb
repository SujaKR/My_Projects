# %% [markdown]
# #  Web Scraping for Indeed.com & Predicting Salaries
# This project is a test of three major skills: collecting data by scraping a website, using natural language processing, and building a binary classifier.
#
# The first part of the project was focused on scraping Indeed.com. This notebook focused on using natural language processing and building models using job postings with salary information to predict salaries.
#
#
# Data Collection:
#
# I used Beautiful soup to scrape the data from the site. I collected salary information for data analyst and data scientist jobs from Indeed. Then using the location, title, and summary of the job I attempted to predict the salary of the job. For job posting sites, this would be extraordinarily useful.
#
# One of the challenge I faced during data collection is that not all job postings on Indeed have a salary listed. To work around this, I created a simple try/except statement to return 'NA' if there was no salary listed. Since I am trying to predict salaries, I had to filter my results down to only include the job postings that listed salaries.
# The next step was to compute the median salary of my results, which came out to be $100,000 and then I created a binary variable for each job - 1 if the salary was above the median and 0 if the salary was below the median.
#
# Models:
#
# I approached this as a classification problem and used Logistic Regression, Decision Tree Classifier and Random Forest classifier. I predicted the Salary label as high or low based on the following parameters:
# Job Title, Job Location and Job Summary
# For the job title and job summary models, I used natural language processing to predict the salary class based on the various words that appeared.
#
# According to my analysis the following five cities were top in the chart in predicting the median salary:
#
# 1. Canberra ACT
# 2. Sydney Central Business District NSW
# 3. Sydney NSW
# 4. Chatswood NSW
# 5. Melbourne VIC
# My finding is that in Canberra most of the jobs are Contract and government jobs so the median price is higher than other cities.
#
# And the skills required for highly paid Data Analysts are good data analysis skills, good understanding of data,experience. And SQL knowledge is required in most of the jobs.
#
# And the top Job Titles having high salary are as below:
#
# 1. Datahub data analyst
# 2. Senior data analyst
# 3. Lead data scientist
# 4. Audience data analyst
# 5. Digital  Data Analyst
# 6. Data analyst consultant
#
# As an employer which is a contracting company, the results can tell us how much a job candidate might be worth based on the role for which they are being hired and the skills that are required for that role. For example, a data analyst with proficient good data analysis skills might be paid more. As we can see from the result contract jobs are highly paid than permanent jobs which influence the model outcome.

# %%
import pandas as pd
import csv
import numpy as np
import seaborn as sns
from warnings import simplefilter
# ignore all future warnings
simplefilter(action='ignore', category = FutureWarning)
from sklearn import metrics
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
#loading the scraped data analyst jobs from indeed.
df = pd.read_csv('indeed_data_analyst.csv')

# %% [markdown]
# # EDA

# %%
df.head(30)
df.shape
# Out:
# (3097, 6)

# %%
df.Salary.isnull().sum()
# Out:
# 2479

# %%
#dropping the Unnamed column
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df_salary=df.dropna()
df_salary.shape
# Out:
# (615, 5)

# %%
#df_salary.drop_duplicates(subset='Summary',inplace=True)

# %%
df_salary.shape
# Out:
# (615, 5)

# %%
# Take commas,dollar sign and text'a year' out 
df_salary['Salary'].replace(to_replace=['\$',',',' a year'], value='', inplace=True,regex=True)
#df_salary
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:6586: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
df_salary['new'] =df_salary['Salary'].str.extractall('(\d+)')[0].unstack().astype(float).mean(1)
    
df_salary
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                                     Company         Location  \
# 1            Cognizant Technology Solutions    Melbourne VIC
# 3            Cognizant Technology Solutions       Sydney NSW
# 4                                    Ignite    Melbourne VIC
# 7                             Publicis Emil    Melbourne VIC
# 8            Agency for Clinical Innovation    Chatswood NSW
# 15                  City of Greater Geelong      Geelong VIC
# 25          University of New England (UNE)     Armidale NSW
# 28                                   Aginic    Melbourne VIC
# 31           Cognizant Technology Solutions       Sydney NSW
# 32                                   Ignite    Melbourne VIC
# 35           Cognizant Technology Solutions    Melbourne VIC
# 36           Cognizant Technology Solutions       Sydney NSW
# 49                                   Ignite    Melbourne VIC
# 52           Cognizant Technology Solutions    Melbourne VIC
# 54                                   Ignite    Melbourne VIC
# 56           Cognizant Technology Solutions    Melbourne VIC
# 59                  University of Melbourne    Parkville VIC
# 61                                     koji    Melbourne VIC
# 74                                   Ignite    Melbourne VIC
# 85           Cognizant Technology Solutions       Sydney NSW
# 86           Cognizant Technology Solutions    Melbourne VIC
# 90                                   Ignite    Melbourne VIC
# 92           Cognizant Technology Solutions       Sydney NSW
# 97                                      IBM    Melbourne VIC
# 105          Cognizant Technology Solutions    Melbourne VIC
# 106          Cognizant Technology Solutions    Melbourne VIC
# 109                                  Ignite    Melbourne VIC
# 111                        GapMaps Pty Ltd.    Docklands VIC
# 119                     Consultel Solutions    Melbourne VIC
# 128                    Bayside City Council  Sandringham VIC
# ...                                     ...              ...
# 2995                           Michael Page    Melbourne VIC
# 2999                      Bluefin Resources    Melbourne VIC
# 3000         Cognizant Technology Solutions    Melbourne VIC
# 3003                                 Ignite    Melbourne VIC
# 3007                             Pet Circle       Sydney NSW
# 3011                           Michael Page    Melbourne VIC
# 3014         Cognizant Technology Solutions    Melbourne VIC
# 3017                                 Ignite    Melbourne VIC
# 3018                                 Ignite     Canberra ACT
# 3022                             Pet Circle       Sydney NSW
# 3026                           Michael Page    Melbourne VIC
# 3030                      Bluefin Resources    Melbourne VIC
# 3031         Cognizant Technology Solutions    Melbourne VIC
# 3034                                 Ignite    Melbourne VIC
# 3038                             Pet Circle       Sydney NSW
# 3042                           Michael Page    Melbourne VIC
# 3045         Cognizant Technology Solutions    Melbourne VIC
# 3048                                 Ignite    Melbourne VIC
# 3051                                 Ignite     Canberra ACT
# 3055                             Pet Circle       Sydney NSW
# 3059                           Michael Page    Melbourne VIC
# 3062         Cognizant Technology Solutions    Melbourne VIC
# 3065                                 Ignite    Melbourne VIC
# 3066                                 Ignite     Canberra ACT
# 3077  Clenergy (Xiamen) Technology Co., Ltd    Melbourne VIC
# 3079         Cognizant Technology Solutions    Melbourne VIC
# 3082                                 Ignite    Melbourne VIC
# 3091  Clenergy (Xiamen) Technology Co., Ltd    Melbourne VIC
# 3093         Cognizant Technology Solutions    Melbourne VIC
# 3096                                 Ignite    Melbourne VIC
#
#                 Salary                                          Job Title  \
# 1       90000 - 110000                                       Data Analyst
# 3        60000 - 90000                               DataHub Data Analyst
# 4      600 - 700 a day                                   Business Analyst
# 7        70000 - 90000                                       Data Analyst
# 8      110961 - 126496                         Data & Statistical Analyst
# 15       83508 - 90180                                       Data Analyst
# 25       76549 - 84141                              Academic Data Analyst
# 28       60000 - 70000                           Data Analyst (Melbourne)
# 31       60000 - 90000                               DataHub Data Analyst
# 32     600 - 700 a day                                   Business Analyst
# 35      90000 - 110000                                       Data Analyst
# 36       60000 - 90000                               DataHub Data Analyst
# 49     600 - 700 a day                                   Business Analyst
# 52      90000 - 110000                                       Data Analyst
# 54     600 - 700 a day                                   Business Analyst
# 56      90000 - 110000                                       Data Analyst
# 59     103409 - 111927                     FINANCE TRANSFORMATION ANALYST
# 61       60000 - 70000  Market Research Consultant - Data Visualisatio...
# 74     600 - 700 a day                                   Business Analyst
# 85       60000 - 90000                               DataHub Data Analyst
# 86      90000 - 110000                                       Data Analyst
# 90     600 - 700 a day                                   Business Analyst
# 92       60000 - 90000                               DataHub Data Analyst
# 97               89250  IBM Research Scientist Data Scientist – Melbourne
# 105     90000 - 110000                                       Data Analyst
# 106     90000 - 110000                                       Data Analyst
# 109    600 - 700 a day                                   Business Analyst
# 111              70000                        GIS Analyst / GIS Scientist
# 119      65000 - 66000                             Data Engineer - Python
# 128              87391              3D Spatial Information System Analyst
# ...                ...                                                ...
# 2995   500 - 650 a day                                   Business Analyst
# 2999   110000 - 130000                                  Reporting Analyst
# 3000    90000 - 110000                                       Data Analyst
# 3003   600 - 700 a day                                   Business Analyst
# 3007    70000 - 100000                          Customer Insights Analyst
# 3011   500 - 650 a day                                   Business Analyst
# 3014    90000 - 110000                                       Data Analyst
# 3017   600 - 700 a day                                   Business Analyst
# 3018  80 - 120 an hour                                       Data Analyst
# 3022    70000 - 100000                          Customer Insights Analyst
# 3026   500 - 650 a day                                   Business Analyst
# 3030   110000 - 130000                                  Reporting Analyst
# 3031    90000 - 110000                                       Data Analyst
# 3034   600 - 700 a day                                   Business Analyst
# 3038    70000 - 100000                          Customer Insights Analyst
# 3042   500 - 650 a day                                   Business Analyst
# 3045    90000 - 110000                                       Data Analyst
# 3048   600 - 700 a day                                   Business Analyst
# 3051  80 - 120 an hour                                       Data Analyst
# 3055    70000 - 100000                          Customer Insights Analyst
# 3059   500 - 650 a day                                   Business Analyst
# 3062    90000 - 110000                                       Data Analyst
# 3065   600 - 700 a day                                   Business Analyst
# 3066  80 - 120 an hour                                       Data Analyst
# 3077    60000 - 120000                           International IT Manager
# 3079    90000 - 110000                                       Data Analyst
# 3082   600 - 700 a day                                   Business Analyst
# 3091    60000 - 120000                           International IT Manager
# 3093    90000 - 110000                                       Data Analyst
# 3096   600 - 700 a day                                   Business Analyst
#
#                                                 Summary       new
# 1     Good understanding of Data Analysis and data m...  100000.0
# 3     Cognizant hiring for DataHub Data Analyst with...   75000.0
# 4     5+ years’ experience in analysis, data managem...     650.0
# 7     Collaboration with global data team to provide...   80000.0
# 8     An experienced data analyst who has worked wit...  118728.5
# 15    The Data analyst positively contributes to the...   86844.0
# 25    Working from either UNE Armidale or the UNE Sy...   80345.0
# 28    We are looking for motivated and passionate Da...   65000.0
# 31    Cognizant hiring for DataHub Data Analyst with...   75000.0
# 32    5+ years’ experience in analysis, data managem...     650.0
# 35    Good understanding of Data Analysis and data m...  100000.0
# 36    Cognizant hiring for DataHub Data Analyst with...   75000.0
# 49    5+ years’ experience in analysis, data managem...     650.0
# 52    Good understanding of Data Analysis and data m...  100000.0
# 54    5+ years’ experience in analysis, data managem...     650.0
# 56    Good understanding of Data Analysis and data m...  100000.0
# 59    Ideally, this individual will also have experi...  107668.0
# 61    Dealing with data providers and other data ana...   65000.0
# 74    5+ years’ experience in analysis, data managem...     650.0
# 85    Cognizant hiring for DataHub Data Analyst with...   75000.0
# 86    Good understanding of Data Analysis and data m...  100000.0
# 90    5+ years’ experience in analysis, data managem...     650.0
# 92    Cognizant hiring for DataHub Data Analyst with...   75000.0
# 97    IBM Research Scientist Data Scientist – Melbou...   89250.0
# 105   Good understanding of Data Analysis and data m...  100000.0
# 106   Good understanding of Data Analysis and data m...  100000.0
# 109   5+ years’ experience in analysis, data managem...     650.0
# 111   Produce reports on geographic data utilizing d...   70000.0
# 119   At least 4 years of relevant hands on coding e...   65500.0
# 128   PD & KSC_3D SIS Analyst Position.DOCX. We have...   87391.0
# ...                                                 ...       ...
# 2995  Minimum 2 years of experience as a Business An...     575.0
# 2999  Extract data from various sources. Perform dat...  120000.0
# 3000  Good understanding of Data Analysis and data m...  100000.0
# 3003  5+ years’ experience in analysis, data managem...     650.0
# 3007  Working closely with key internal leaders to i...   85000.0
# 3011  Minimum 2 years of experience as a Business An...     575.0
# 3014  Good understanding of Data Analysis and data m...  100000.0
# 3017  5+ years’ experience in analysis, data managem...     650.0
# 3018  Strong R skills for data exploration purposes,...     100.0
# 3022  Working closely with key internal leaders to i...   85000.0
# 3026  Minimum 2 years of experience as a Business An...     575.0
# 3030  Extract data from various sources. Perform dat...  120000.0
# 3031  Good understanding of Data Analysis and data m...  100000.0
# 3034  5+ years’ experience in analysis, data managem...     650.0
# 3038  Working closely with key internal leaders to i...   85000.0
# 3042  Minimum 2 years of experience as a Business An...     575.0
# 3045  Good understanding of Data Analysis and data m...  100000.0
# 3048  5+ years’ experience in analysis, data managem...     650.0
# 3051  Strong R skills for data exploration purposes,...     100.0
# 3055  Working closely with key internal leaders to i...   85000.0
# 3059  Minimum 2 years of experience as a Business An...     575.0
# 3062  Good understanding of Data Analysis and data m...  100000.0
# 3065  5+ years’ experience in analysis, data managem...     650.0
# 3066  Strong R skills for data exploration purposes,...     100.0
# 3077  Fully experienced with SAP B1, Ecommerce and B...   90000.0
# 3079  Good understanding of Data Analysis and data m...  100000.0
# 3082  5+ years’ experience in analysis, data managem...     650.0
# 3091  International IT Manager, Global IT Manager. F...   90000.0
# 3093  Solid SQL skill and be able analysis the data ...  100000.0
# 3096  Demonstrated experience as Analyst with abilit...     650.0
#
# [615 rows x 6 columns]

# %%
#converting the salary formats to per year

m1 = df_salary['Salary'].str.contains('month')
m2 = df_salary['Salary'].str.contains('day') | df_salary['Salary'].str.contains('p/d')
m3 = df_salary['Salary'].str.contains('hour') |df_salary['Salary'].str.contains('p/hr')
df_salary['Annual_salary'] =np.select([m1,m2,m3],[df_salary['new']*12,df_salary['new']*269,df_salary['new']*8*269], default=df_salary['new'])
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_salary.Location.value_counts().head(7)
# Out:
# Melbourne VIC                           406
# Sydney NSW                              114
# Canberra ACT                             20
# Sydney Central Business District NSW      7
# Geelong VIC                               6
# North Sydney NSW                          6
# Brisbane QLD                              6
# Name: Location, dtype: int64

# %%
df2=df_salary.groupby('Job Title').median().head(20)

# %%
df2.sort_values(by='Annual_salary',ascending=0)
# Out:
#                                                          new  Annual_salary
# Job Title
# Application Specialist, Data Analyst - Global F...  170000.0       170000.0
# Analytics Lead/ Data Scientist                      145000.0       145000.0
# BI Analyst - Tableau                                140000.0       140000.0
# Associate / Data Science delivery lead              125000.0       125000.0
# APS6 Data Analyst                                       54.0       116208.0
# APS4 Business Analyst                                   52.5       112980.0
# APS6 Senior Data Analyst                                50.5       108676.0
# Analyst                                                 45.0        96840.0
# APS4 Data Analyst - SQL / R Code                        41.0        88232.0
# 3D Spatial Information System Analyst                87391.0        87391.0
# APS 5, APS 6 - Learning & Development Advisor (...   82893.0        82893.0
# Applications Support Analyst                         82500.0        82500.0
# Academic Data Analyst                                80345.0        80345.0
# Audience/ Data Analyst- Digital Media                80000.0        80000.0
# Assistant Analyst/Auditor                            73271.5        73271.5
# Audit & Assurance - Quantitative Finance Soluti...   70000.0        70000.0
# Analyst - IT Audit                                      32.5        69940.0
# Analyst Consultant                                   65000.0        65000.0
# Associate Investment Analyst - Investment Research   65000.0        65000.0
# 3 x Data Engineer - Contract - Fin Services - $...     800.0          800.0

# %%
#finding the median salary
median=np.median(df_salary_new['Annual_salary'])
median
# Out:
# 100000.0

# %% [markdown]
# ### Creating label 'Job Type' for salary as high and low based on median salary

# %%
df_salary['Job_Type'] = [1 if x>median else 0 for x in df_salary.Annual_salary]
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_salary
# Out:
#                                     Company         Location  \
# 1            Cognizant Technology Solutions    Melbourne VIC
# 3            Cognizant Technology Solutions       Sydney NSW
# 4                                    Ignite    Melbourne VIC
# 7                             Publicis Emil    Melbourne VIC
# 8            Agency for Clinical Innovation    Chatswood NSW
# 15                  City of Greater Geelong      Geelong VIC
# 25          University of New England (UNE)     Armidale NSW
# 28                                   Aginic    Melbourne VIC
# 31           Cognizant Technology Solutions       Sydney NSW
# 32                                   Ignite    Melbourne VIC
# 35           Cognizant Technology Solutions    Melbourne VIC
# 36           Cognizant Technology Solutions       Sydney NSW
# 49                                   Ignite    Melbourne VIC
# 52           Cognizant Technology Solutions    Melbourne VIC
# 54                                   Ignite    Melbourne VIC
# 56           Cognizant Technology Solutions    Melbourne VIC
# 59                  University of Melbourne    Parkville VIC
# 61                                     koji    Melbourne VIC
# 74                                   Ignite    Melbourne VIC
# 85           Cognizant Technology Solutions       Sydney NSW
# 86           Cognizant Technology Solutions    Melbourne VIC
# 90                                   Ignite    Melbourne VIC
# 92           Cognizant Technology Solutions       Sydney NSW
# 97                                      IBM    Melbourne VIC
# 105          Cognizant Technology Solutions    Melbourne VIC
# 106          Cognizant Technology Solutions    Melbourne VIC
# 109                                  Ignite    Melbourne VIC
# 111                        GapMaps Pty Ltd.    Docklands VIC
# 119                     Consultel Solutions    Melbourne VIC
# 128                    Bayside City Council  Sandringham VIC
# ...                                     ...              ...
# 2995                           Michael Page    Melbourne VIC
# 2999                      Bluefin Resources    Melbourne VIC
# 3000         Cognizant Technology Solutions    Melbourne VIC
# 3003                                 Ignite    Melbourne VIC
# 3007                             Pet Circle       Sydney NSW
# 3011                           Michael Page    Melbourne VIC
# 3014         Cognizant Technology Solutions    Melbourne VIC
# 3017                                 Ignite    Melbourne VIC
# 3018                                 Ignite     Canberra ACT
# 3022                             Pet Circle       Sydney NSW
# 3026                           Michael Page    Melbourne VIC
# 3030                      Bluefin Resources    Melbourne VIC
# 3031         Cognizant Technology Solutions    Melbourne VIC
# 3034                                 Ignite    Melbourne VIC
# 3038                             Pet Circle       Sydney NSW
# 3042                           Michael Page    Melbourne VIC
# 3045         Cognizant Technology Solutions    Melbourne VIC
# 3048                                 Ignite    Melbourne VIC
# 3051                                 Ignite     Canberra ACT
# 3055                             Pet Circle       Sydney NSW
# 3059                           Michael Page    Melbourne VIC
# 3062         Cognizant Technology Solutions    Melbourne VIC
# 3065                                 Ignite    Melbourne VIC
# 3066                                 Ignite     Canberra ACT
# 3077  Clenergy (Xiamen) Technology Co., Ltd    Melbourne VIC
# 3079         Cognizant Technology Solutions    Melbourne VIC
# 3082                                 Ignite    Melbourne VIC
# 3091  Clenergy (Xiamen) Technology Co., Ltd    Melbourne VIC
# 3093         Cognizant Technology Solutions    Melbourne VIC
# 3096                                 Ignite    Melbourne VIC
#
#                 Salary                                          Job Title  \
# 1       90000 - 110000                                       Data Analyst
# 3        60000 - 90000                               DataHub Data Analyst
# 4      600 - 700 a day                                   Business Analyst
# 7        70000 - 90000                                       Data Analyst
# 8      110961 - 126496                         Data & Statistical Analyst
# 15       83508 - 90180                                       Data Analyst
# 25       76549 - 84141                              Academic Data Analyst
# 28       60000 - 70000                           Data Analyst (Melbourne)
# 31       60000 - 90000                               DataHub Data Analyst
# 32     600 - 700 a day                                   Business Analyst
# 35      90000 - 110000                                       Data Analyst
# 36       60000 - 90000                               DataHub Data Analyst
# 49     600 - 700 a day                                   Business Analyst
# 52      90000 - 110000                                       Data Analyst
# 54     600 - 700 a day                                   Business Analyst
# 56      90000 - 110000                                       Data Analyst
# 59     103409 - 111927                     FINANCE TRANSFORMATION ANALYST
# 61       60000 - 70000  Market Research Consultant - Data Visualisatio...
# 74     600 - 700 a day                                   Business Analyst
# 85       60000 - 90000                               DataHub Data Analyst
# 86      90000 - 110000                                       Data Analyst
# 90     600 - 700 a day                                   Business Analyst
# 92       60000 - 90000                               DataHub Data Analyst
# 97               89250  IBM Research Scientist Data Scientist – Melbourne
# 105     90000 - 110000                                       Data Analyst
# 106     90000 - 110000                                       Data Analyst
# 109    600 - 700 a day                                   Business Analyst
# 111              70000                        GIS Analyst / GIS Scientist
# 119      65000 - 66000                             Data Engineer - Python
# 128              87391              3D Spatial Information System Analyst
# ...                ...                                                ...
# 2995   500 - 650 a day                                   Business Analyst
# 2999   110000 - 130000                                  Reporting Analyst
# 3000    90000 - 110000                                       Data Analyst
# 3003   600 - 700 a day                                   Business Analyst
# 3007    70000 - 100000                          Customer Insights Analyst
# 3011   500 - 650 a day                                   Business Analyst
# 3014    90000 - 110000                                       Data Analyst
# 3017   600 - 700 a day                                   Business Analyst
# 3018  80 - 120 an hour                                       Data Analyst
# 3022    70000 - 100000                          Customer Insights Analyst
# 3026   500 - 650 a day                                   Business Analyst
# 3030   110000 - 130000                                  Reporting Analyst
# 3031    90000 - 110000                                       Data Analyst
# 3034   600 - 700 a day                                   Business Analyst
# 3038    70000 - 100000                          Customer Insights Analyst
# 3042   500 - 650 a day                                   Business Analyst
# 3045    90000 - 110000                                       Data Analyst
# 3048   600 - 700 a day                                   Business Analyst
# 3051  80 - 120 an hour                                       Data Analyst
# 3055    70000 - 100000                          Customer Insights Analyst
# 3059   500 - 650 a day                                   Business Analyst
# 3062    90000 - 110000                                       Data Analyst
# 3065   600 - 700 a day                                   Business Analyst
# 3066  80 - 120 an hour                                       Data Analyst
# 3077    60000 - 120000                           International IT Manager
# 3079    90000 - 110000                                       Data Analyst
# 3082   600 - 700 a day                                   Business Analyst
# 3091    60000 - 120000                           International IT Manager
# 3093    90000 - 110000                                       Data Analyst
# 3096   600 - 700 a day                                   Business Analyst
#
#                                                 Summary       new  \
# 1     Good understanding of Data Analysis and data m...  100000.0
# 3     Cognizant hiring for DataHub Data Analyst with...   75000.0
# 4     5+ years’ experience in analysis, data managem...     650.0
# 7     Collaboration with global data team to provide...   80000.0
# 8     An experienced data analyst who has worked wit...  118728.5
# 15    The Data analyst positively contributes to the...   86844.0
# 25    Working from either UNE Armidale or the UNE Sy...   80345.0
# 28    We are looking for motivated and passionate Da...   65000.0
# 31    Cognizant hiring for DataHub Data Analyst with...   75000.0
# 32    5+ years’ experience in analysis, data managem...     650.0
# 35    Good understanding of Data Analysis and data m...  100000.0
# 36    Cognizant hiring for DataHub Data Analyst with...   75000.0
# 49    5+ years’ experience in analysis, data managem...     650.0
# 52    Good understanding of Data Analysis and data m...  100000.0
# 54    5+ years’ experience in analysis, data managem...     650.0
# 56    Good understanding of Data Analysis and data m...  100000.0
# 59    Ideally, this individual will also have experi...  107668.0
# 61    Dealing with data providers and other data ana...   65000.0
# 74    5+ years’ experience in analysis, data managem...     650.0
# 85    Cognizant hiring for DataHub Data Analyst with...   75000.0
# 86    Good understanding of Data Analysis and data m...  100000.0
# 90    5+ years’ experience in analysis, data managem...     650.0
# 92    Cognizant hiring for DataHub Data Analyst with...   75000.0
# 97    IBM Research Scientist Data Scientist – Melbou...   89250.0
# 105   Good understanding of Data Analysis and data m...  100000.0
# 106   Good understanding of Data Analysis and data m...  100000.0
# 109   5+ years’ experience in analysis, data managem...     650.0
# 111   Produce reports on geographic data utilizing d...   70000.0
# 119   At least 4 years of relevant hands on coding e...   65500.0
# 128   PD & KSC_3D SIS Analyst Position.DOCX. We have...   87391.0
# ...                                                 ...       ...
# 2995  Minimum 2 years of experience as a Business An...     575.0
# 2999  Extract data from various sources. Perform dat...  120000.0
# 3000  Good understanding of Data Analysis and data m...  100000.0
# 3003  5+ years’ experience in analysis, data managem...     650.0
# 3007  Working closely with key internal leaders to i...   85000.0
# 3011  Minimum 2 years of experience as a Business An...     575.0
# 3014  Good understanding of Data Analysis and data m...  100000.0
# 3017  5+ years’ experience in analysis, data managem...     650.0
# 3018  Strong R skills for data exploration purposes,...     100.0
# 3022  Working closely with key internal leaders to i...   85000.0
# 3026  Minimum 2 years of experience as a Business An...     575.0
# 3030  Extract data from various sources. Perform dat...  120000.0
# 3031  Good understanding of Data Analysis and data m...  100000.0
# 3034  5+ years’ experience in analysis, data managem...     650.0
# 3038  Working closely with key internal leaders to i...   85000.0
# 3042  Minimum 2 years of experience as a Business An...     575.0
# 3045  Good understanding of Data Analysis and data m...  100000.0
# 3048  5+ years’ experience in analysis, data managem...     650.0
# 3051  Strong R skills for data exploration purposes,...     100.0
# 3055  Working closely with key internal leaders to i...   85000.0
# 3059  Minimum 2 years of experience as a Business An...     575.0
# 3062  Good understanding of Data Analysis and data m...  100000.0
# 3065  5+ years’ experience in analysis, data managem...     650.0
# 3066  Strong R skills for data exploration purposes,...     100.0
# 3077  Fully experienced with SAP B1, Ecommerce and B...   90000.0
# 3079  Good understanding of Data Analysis and data m...  100000.0
# 3082  5+ years’ experience in analysis, data managem...     650.0
# 3091  International IT Manager, Global IT Manager. F...   90000.0
# 3093  Solid SQL skill and be able analysis the data ...  100000.0
# 3096  Demonstrated experience as Analyst with abilit...     650.0
#
#       Annual_salary  Job_Type
# 1          100000.0         0
# 3           75000.0         0
# 4          174850.0         1
# 7           80000.0         0
# 8          118728.5         1
# 15          86844.0         0
# 25          80345.0         0
# 28          65000.0         0
# 31          75000.0         0
# 32         174850.0         1
# 35         100000.0         0
# 36          75000.0         0
# 49         174850.0         1
# 52         100000.0         0
# 54         174850.0         1
# 56         100000.0         0
# 59         107668.0         1
# 61          65000.0         0
# 74         174850.0         1
# 85          75000.0         0
# 86         100000.0         0
# 90         174850.0         1
# 92          75000.0         0
# 97          89250.0         0
# 105        100000.0         0
# 106        100000.0         0
# 109        174850.0         1
# 111         70000.0         0
# 119         65500.0         0
# 128         87391.0         0
# ...             ...       ...
# 2995       154675.0         1
# 2999       120000.0         1
# 3000       100000.0         0
# 3003       174850.0         1
# 3007        85000.0         0
# 3011       154675.0         1
# 3014       100000.0         0
# 3017       174850.0         1
# 3018       215200.0         1
# 3022        85000.0         0
# 3026       154675.0         1
# 3030       120000.0         1
# 3031       100000.0         0
# 3034       174850.0         1
# 3038        85000.0         0
# 3042       154675.0         1
# 3045       100000.0         0
# 3048       174850.0         1
# 3051       215200.0         1
# 3055        85000.0         0
# 3059       154675.0         1
# 3062       100000.0         0
# 3065       174850.0         1
# 3066       215200.0         1
# 3077        90000.0         0
# 3079       100000.0         0
# 3082       174850.0         1
# 3091        90000.0         0
# 3093       100000.0         0
# 3096       174850.0         1
#
# [615 rows x 8 columns]

# %%
#Dropping the unwanted columns and resetting the index

df_salary.reset_index(drop=True,inplace=True)
df_salary.drop(['Salary','new'],axis=1,inplace=True)
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
#loading the cleaned data to csv file
df_salary.to_csv('indeed_data_analyst_cleaned.csv', encoding='utf-8')
df_salary_data = pd.read_csv('indeed_data_analyst_cleaned.csv')

# %%
df_salary_data
# Out:
#      Unnamed: 0                                Company         Location  \
# 0             0         Cognizant Technology Solutions    Melbourne VIC
# 1             1         Cognizant Technology Solutions       Sydney NSW
# 2             2                                 Ignite    Melbourne VIC
# 3             3                          Publicis Emil    Melbourne VIC
# 4             4         Agency for Clinical Innovation    Chatswood NSW
# 5             5                City of Greater Geelong      Geelong VIC
# 6             6        University of New England (UNE)     Armidale NSW
# 7             7                                 Aginic    Melbourne VIC
# 8             8         Cognizant Technology Solutions       Sydney NSW
# 9             9                                 Ignite    Melbourne VIC
# 10           10         Cognizant Technology Solutions    Melbourne VIC
# 11           11         Cognizant Technology Solutions       Sydney NSW
# 12           12                                 Ignite    Melbourne VIC
# 13           13         Cognizant Technology Solutions    Melbourne VIC
# 14           14                                 Ignite    Melbourne VIC
# 15           15         Cognizant Technology Solutions    Melbourne VIC
# 16           16                University of Melbourne    Parkville VIC
# 17           17                                   koji    Melbourne VIC
# 18           18                                 Ignite    Melbourne VIC
# 19           19         Cognizant Technology Solutions       Sydney NSW
# 20           20         Cognizant Technology Solutions    Melbourne VIC
# 21           21                                 Ignite    Melbourne VIC
# 22           22         Cognizant Technology Solutions       Sydney NSW
# 23           23                                    IBM    Melbourne VIC
# 24           24         Cognizant Technology Solutions    Melbourne VIC
# 25           25         Cognizant Technology Solutions    Melbourne VIC
# 26           26                                 Ignite    Melbourne VIC
# 27           27                       GapMaps Pty Ltd.    Docklands VIC
# 28           28                    Consultel Solutions    Melbourne VIC
# 29           29                   Bayside City Council  Sandringham VIC
# ..          ...                                    ...              ...
# 585         585                           Michael Page    Melbourne VIC
# 586         586                      Bluefin Resources    Melbourne VIC
# 587         587         Cognizant Technology Solutions    Melbourne VIC
# 588         588                                 Ignite    Melbourne VIC
# 589         589                             Pet Circle       Sydney NSW
# 590         590                           Michael Page    Melbourne VIC
# 591         591         Cognizant Technology Solutions    Melbourne VIC
# 592         592                                 Ignite    Melbourne VIC
# 593         593                                 Ignite     Canberra ACT
# 594         594                             Pet Circle       Sydney NSW
# 595         595                           Michael Page    Melbourne VIC
# 596         596                      Bluefin Resources    Melbourne VIC
# 597         597         Cognizant Technology Solutions    Melbourne VIC
# 598         598                                 Ignite    Melbourne VIC
# 599         599                             Pet Circle       Sydney NSW
# 600         600                           Michael Page    Melbourne VIC
# 601         601         Cognizant Technology Solutions    Melbourne VIC
# 602         602                                 Ignite    Melbourne VIC
# 603         603                                 Ignite     Canberra ACT
# 604         604                             Pet Circle       Sydney NSW
# 605         605                           Michael Page    Melbourne VIC
# 606         606         Cognizant Technology Solutions    Melbourne VIC
# 607         607                                 Ignite    Melbourne VIC
# 608         608                                 Ignite     Canberra ACT
# 609         609  Clenergy (Xiamen) Technology Co., Ltd    Melbourne VIC
# 610         610         Cognizant Technology Solutions    Melbourne VIC
# 611         611                                 Ignite    Melbourne VIC
# 612         612  Clenergy (Xiamen) Technology Co., Ltd    Melbourne VIC
# 613         613         Cognizant Technology Solutions    Melbourne VIC
# 614         614                                 Ignite    Melbourne VIC
#
#                                              Job Title  \
# 0                                         Data Analyst
# 1                                 DataHub Data Analyst
# 2                                     Business Analyst
# 3                                         Data Analyst
# 4                           Data & Statistical Analyst
# 5                                         Data Analyst
# 6                                Academic Data Analyst
# 7                             Data Analyst (Melbourne)
# 8                                 DataHub Data Analyst
# 9                                     Business Analyst
# 10                                        Data Analyst
# 11                                DataHub Data Analyst
# 12                                    Business Analyst
# 13                                        Data Analyst
# 14                                    Business Analyst
# 15                                        Data Analyst
# 16                      FINANCE TRANSFORMATION ANALYST
# 17   Market Research Consultant - Data Visualisatio...
# 18                                    Business Analyst
# 19                                DataHub Data Analyst
# 20                                        Data Analyst
# 21                                    Business Analyst
# 22                                DataHub Data Analyst
# 23   IBM Research Scientist Data Scientist – Melbourne
# 24                                        Data Analyst
# 25                                        Data Analyst
# 26                                    Business Analyst
# 27                         GIS Analyst / GIS Scientist
# 28                              Data Engineer - Python
# 29               3D Spatial Information System Analyst
# ..                                                 ...
# 585                                   Business Analyst
# 586                                  Reporting Analyst
# 587                                       Data Analyst
# 588                                   Business Analyst
# 589                          Customer Insights Analyst
# 590                                   Business Analyst
# 591                                       Data Analyst
# 592                                   Business Analyst
# 593                                       Data Analyst
# 594                          Customer Insights Analyst
# 595                                   Business Analyst
# 596                                  Reporting Analyst
# 597                                       Data Analyst
# 598                                   Business Analyst
# 599                          Customer Insights Analyst
# 600                                   Business Analyst
# 601                                       Data Analyst
# 602                                   Business Analyst
# 603                                       Data Analyst
# 604                          Customer Insights Analyst
# 605                                   Business Analyst
# 606                                       Data Analyst
# 607                                   Business Analyst
# 608                                       Data Analyst
# 609                           International IT Manager
# 610                                       Data Analyst
# 611                                   Business Analyst
# 612                           International IT Manager
# 613                                       Data Analyst
# 614                                   Business Analyst
#
#                                                Summary  Annual_salary  \
# 0    Good understanding of Data Analysis and data m...       100000.0
# 1    Cognizant hiring for DataHub Data Analyst with...        75000.0
# 2    5+ years’ experience in analysis, data managem...       174850.0
# 3    Collaboration with global data team to provide...        80000.0
# 4    An experienced data analyst who has worked wit...       118728.5
# 5    The Data analyst positively contributes to the...        86844.0
# 6    Working from either UNE Armidale or the UNE Sy...        80345.0
# 7    We are looking for motivated and passionate Da...        65000.0
# 8    Cognizant hiring for DataHub Data Analyst with...        75000.0
# 9    5+ years’ experience in analysis, data managem...       174850.0
# 10   Good understanding of Data Analysis and data m...       100000.0
# 11   Cognizant hiring for DataHub Data Analyst with...        75000.0
# 12   5+ years’ experience in analysis, data managem...       174850.0
# 13   Good understanding of Data Analysis and data m...       100000.0
# 14   5+ years’ experience in analysis, data managem...       174850.0
# 15   Good understanding of Data Analysis and data m...       100000.0
# 16   Ideally, this individual will also have experi...       107668.0
# 17   Dealing with data providers and other data ana...        65000.0
# 18   5+ years’ experience in analysis, data managem...       174850.0
# 19   Cognizant hiring for DataHub Data Analyst with...        75000.0
# 20   Good understanding of Data Analysis and data m...       100000.0
# 21   5+ years’ experience in analysis, data managem...       174850.0
# 22   Cognizant hiring for DataHub Data Analyst with...        75000.0
# 23   IBM Research Scientist Data Scientist – Melbou...        89250.0
# 24   Good understanding of Data Analysis and data m...       100000.0
# 25   Good understanding of Data Analysis and data m...       100000.0
# 26   5+ years’ experience in analysis, data managem...       174850.0
# 27   Produce reports on geographic data utilizing d...        70000.0
# 28   At least 4 years of relevant hands on coding e...        65500.0
# 29   PD & KSC_3D SIS Analyst Position.DOCX. We have...        87391.0
# ..                                                 ...            ...
# 585  Minimum 2 years of experience as a Business An...       154675.0
# 586  Extract data from various sources. Perform dat...       120000.0
# 587  Good understanding of Data Analysis and data m...       100000.0
# 588  5+ years’ experience in analysis, data managem...       174850.0
# 589  Working closely with key internal leaders to i...        85000.0
# 590  Minimum 2 years of experience as a Business An...       154675.0
# 591  Good understanding of Data Analysis and data m...       100000.0
# 592  5+ years’ experience in analysis, data managem...       174850.0
# 593  Strong R skills for data exploration purposes,...       215200.0
# 594  Working closely with key internal leaders to i...        85000.0
# 595  Minimum 2 years of experience as a Business An...       154675.0
# 596  Extract data from various sources. Perform dat...       120000.0
# 597  Good understanding of Data Analysis and data m...       100000.0
# 598  5+ years’ experience in analysis, data managem...       174850.0
# 599  Working closely with key internal leaders to i...        85000.0
# 600  Minimum 2 years of experience as a Business An...       154675.0
# 601  Good understanding of Data Analysis and data m...       100000.0
# 602  5+ years’ experience in analysis, data managem...       174850.0
# 603  Strong R skills for data exploration purposes,...       215200.0
# 604  Working closely with key internal leaders to i...        85000.0
# 605  Minimum 2 years of experience as a Business An...       154675.0
# 606  Good understanding of Data Analysis and data m...       100000.0
# 607  5+ years’ experience in analysis, data managem...       174850.0
# 608  Strong R skills for data exploration purposes,...       215200.0
# 609  Fully experienced with SAP B1, Ecommerce and B...        90000.0
# 610  Good understanding of Data Analysis and data m...       100000.0
# 611  5+ years’ experience in analysis, data managem...       174850.0
# 612  International IT Manager, Global IT Manager. F...        90000.0
# 613  Solid SQL skill and be able analysis the data ...       100000.0
# 614  Demonstrated experience as Analyst with abilit...       174850.0
#
#      Job_Type
# 0           0
# 1           0
# 2           1
# 3           0
# 4           1
# 5           0
# 6           0
# 7           0
# 8           0
# 9           1
# 10          0
# 11          0
# 12          1
# 13          0
# 14          1
# 15          0
# 16          1
# 17          0
# 18          1
# 19          0
# 20          0
# 21          1
# 22          0
# 23          0
# 24          0
# 25          0
# 26          1
# 27          0
# 28          0
# 29          0
# ..        ...
# 585         1
# 586         1
# 587         0
# 588         1
# 589         0
# 590         1
# 591         0
# 592         1
# 593         1
# 594         0
# 595         1
# 596         1
# 597         0
# 598         1
# 599         0
# 600         1
# 601         0
# 602         1
# 603         1
# 604         0
# 605         1
# 606         0
# 607         1
# 608         1
# 609         0
# 610         0
# 611         1
# 612         0
# 613         0
# 614         1
#
# [615 rows x 7 columns]

# %%
df_salary_new =df_salary_data.drop(['Unnamed: 0'],axis=1)

# %%
df_salary_new.shape
# Out:
# (615, 6)

# %% [markdown]
# ###  Setting the target variable as Job_Type(high or low)

# %%
y = df_salary_new["Job_Type"]

# %%
#Calculating the baseline model accuracy
baseline =1-np.mean(y)
print('baseline:', baseline)
# Out:
# baseline: 0.6097560975609756

# %%
ss = StandardScaler()

# %% [markdown]
# ### Predicting salary with location

# %%
df_salary_new['Location']= df_salary_new['Location'].apply(lambda x: 'Melbourne' if x in ['Docklands VIC','St Kilda VIC','Parkville VIC'] else x)

# %%
X = df_salary_new["Location"]
X= pd.get_dummies(X, drop_first=True)
y = df_salary_new["Job_Type"]
# saving the encoded value to a dataframe
df_loc=X

# %%
df_salary_new.shape
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/displayhook.py:271: UserWarning: Output cache limit (currently 1000 entries) hit.
# Flushing oldest 200 entries.
#   'Flushing oldest {cull_count} entries.'.format(sz=sz, cull_count=cull_count))
# (615, 6)

# %%
df_salary_new
# Out:
#                                    Company         Location  \
# 0           Cognizant Technology Solutions    Melbourne VIC
# 1           Cognizant Technology Solutions       Sydney NSW
# 2                                   Ignite    Melbourne VIC
# 3                            Publicis Emil    Melbourne VIC
# 4           Agency for Clinical Innovation    Chatswood NSW
# 5                  City of Greater Geelong      Geelong VIC
# 6          University of New England (UNE)     Armidale NSW
# 7                                   Aginic    Melbourne VIC
# 8           Cognizant Technology Solutions       Sydney NSW
# 9                                   Ignite    Melbourne VIC
# 10          Cognizant Technology Solutions    Melbourne VIC
# 11          Cognizant Technology Solutions       Sydney NSW
# 12                                  Ignite    Melbourne VIC
# 13          Cognizant Technology Solutions    Melbourne VIC
# 14                                  Ignite    Melbourne VIC
# 15          Cognizant Technology Solutions    Melbourne VIC
# 16                 University of Melbourne        Melbourne
# 17                                    koji    Melbourne VIC
# 18                                  Ignite    Melbourne VIC
# 19          Cognizant Technology Solutions       Sydney NSW
# 20          Cognizant Technology Solutions    Melbourne VIC
# 21                                  Ignite    Melbourne VIC
# 22          Cognizant Technology Solutions       Sydney NSW
# 23                                     IBM    Melbourne VIC
# 24          Cognizant Technology Solutions    Melbourne VIC
# 25          Cognizant Technology Solutions    Melbourne VIC
# 26                                  Ignite    Melbourne VIC
# 27                        GapMaps Pty Ltd.        Melbourne
# 28                     Consultel Solutions    Melbourne VIC
# 29                    Bayside City Council  Sandringham VIC
# ..                                     ...              ...
# 585                           Michael Page    Melbourne VIC
# 586                      Bluefin Resources    Melbourne VIC
# 587         Cognizant Technology Solutions    Melbourne VIC
# 588                                 Ignite    Melbourne VIC
# 589                             Pet Circle       Sydney NSW
# 590                           Michael Page    Melbourne VIC
# 591         Cognizant Technology Solutions    Melbourne VIC
# 592                                 Ignite    Melbourne VIC
# 593                                 Ignite     Canberra ACT
# 594                             Pet Circle       Sydney NSW
# 595                           Michael Page    Melbourne VIC
# 596                      Bluefin Resources    Melbourne VIC
# 597         Cognizant Technology Solutions    Melbourne VIC
# 598                                 Ignite    Melbourne VIC
# 599                             Pet Circle       Sydney NSW
# 600                           Michael Page    Melbourne VIC
# 601         Cognizant Technology Solutions    Melbourne VIC
# 602                                 Ignite    Melbourne VIC
# 603                                 Ignite     Canberra ACT
# 604                             Pet Circle       Sydney NSW
# 605                           Michael Page    Melbourne VIC
# 606         Cognizant Technology Solutions    Melbourne VIC
# 607                                 Ignite    Melbourne VIC
# 608                                 Ignite     Canberra ACT
# 609  Clenergy (Xiamen) Technology Co., Ltd    Melbourne VIC
# 610         Cognizant Technology Solutions    Melbourne VIC
# 611                                 Ignite    Melbourne VIC
# 612  Clenergy (Xiamen) Technology Co., Ltd    Melbourne VIC
# 613         Cognizant Technology Solutions    Melbourne VIC
# 614                                 Ignite    Melbourne VIC
#
#                                              Job Title  \
# 0                                         Data Analyst
# 1                                 DataHub Data Analyst
# 2                                     Business Analyst
# 3                                         Data Analyst
# 4                           Data & Statistical Analyst
# 5                                         Data Analyst
# 6                                Academic Data Analyst
# 7                             Data Analyst (Melbourne)
# 8                                 DataHub Data Analyst
# 9                                     Business Analyst
# 10                                        Data Analyst
# 11                                DataHub Data Analyst
# 12                                    Business Analyst
# 13                                        Data Analyst
# 14                                    Business Analyst
# 15                                        Data Analyst
# 16                      FINANCE TRANSFORMATION ANALYST
# 17   Market Research Consultant - Data Visualisatio...
# 18                                    Business Analyst
# 19                                DataHub Data Analyst
# 20                                        Data Analyst
# 21                                    Business Analyst
# 22                                DataHub Data Analyst
# 23   IBM Research Scientist Data Scientist – Melbourne
# 24                                        Data Analyst
# 25                                        Data Analyst
# 26                                    Business Analyst
# 27                         GIS Analyst / GIS Scientist
# 28                              Data Engineer - Python
# 29               3D Spatial Information System Analyst
# ..                                                 ...
# 585                                   Business Analyst
# 586                                  Reporting Analyst
# 587                                       Data Analyst
# 588                                   Business Analyst
# 589                          Customer Insights Analyst
# 590                                   Business Analyst
# 591                                       Data Analyst
# 592                                   Business Analyst
# 593                                       Data Analyst
# 594                          Customer Insights Analyst
# 595                                   Business Analyst
# 596                                  Reporting Analyst
# 597                                       Data Analyst
# 598                                   Business Analyst
# 599                          Customer Insights Analyst
# 600                                   Business Analyst
# 601                                       Data Analyst
# 602                                   Business Analyst
# 603                                       Data Analyst
# 604                          Customer Insights Analyst
# 605                                   Business Analyst
# 606                                       Data Analyst
# 607                                   Business Analyst
# 608                                       Data Analyst
# 609                           International IT Manager
# 610                                       Data Analyst
# 611                                   Business Analyst
# 612                           International IT Manager
# 613                                       Data Analyst
# 614                                   Business Analyst
#
#                                                Summary  Annual_salary  \
# 0    Good understanding of Data Analysis and data m...       100000.0
# 1    Cognizant hiring for DataHub Data Analyst with...        75000.0
# 2    5+ years’ experience in analysis, data managem...       174850.0
# 3    Collaboration with global data team to provide...        80000.0
# 4    An experienced data analyst who has worked wit...       118728.5
# 5    The Data analyst positively contributes to the...        86844.0
# 6    Working from either UNE Armidale or the UNE Sy...        80345.0
# 7    We are looking for motivated and passionate Da...        65000.0
# 8    Cognizant hiring for DataHub Data Analyst with...        75000.0
# 9    5+ years’ experience in analysis, data managem...       174850.0
# 10   Good understanding of Data Analysis and data m...       100000.0
# 11   Cognizant hiring for DataHub Data Analyst with...        75000.0
# 12   5+ years’ experience in analysis, data managem...       174850.0
# 13   Good understanding of Data Analysis and data m...       100000.0
# 14   5+ years’ experience in analysis, data managem...       174850.0
# 15   Good understanding of Data Analysis and data m...       100000.0
# 16   Ideally, this individual will also have experi...       107668.0
# 17   Dealing with data providers and other data ana...        65000.0
# 18   5+ years’ experience in analysis, data managem...       174850.0
# 19   Cognizant hiring for DataHub Data Analyst with...        75000.0
# 20   Good understanding of Data Analysis and data m...       100000.0
# 21   5+ years’ experience in analysis, data managem...       174850.0
# 22   Cognizant hiring for DataHub Data Analyst with...        75000.0
# 23   IBM Research Scientist Data Scientist – Melbou...        89250.0
# 24   Good understanding of Data Analysis and data m...       100000.0
# 25   Good understanding of Data Analysis and data m...       100000.0
# 26   5+ years’ experience in analysis, data managem...       174850.0
# 27   Produce reports on geographic data utilizing d...        70000.0
# 28   At least 4 years of relevant hands on coding e...        65500.0
# 29   PD & KSC_3D SIS Analyst Position.DOCX. We have...        87391.0
# ..                                                 ...            ...
# 585  Minimum 2 years of experience as a Business An...       154675.0
# 586  Extract data from various sources. Perform dat...       120000.0
# 587  Good understanding of Data Analysis and data m...       100000.0
# 588  5+ years’ experience in analysis, data managem...       174850.0
# 589  Working closely with key internal leaders to i...        85000.0
# 590  Minimum 2 years of experience as a Business An...       154675.0
# 591  Good understanding of Data Analysis and data m...       100000.0
# 592  5+ years’ experience in analysis, data managem...       174850.0
# 593  Strong R skills for data exploration purposes,...       215200.0
# 594  Working closely with key internal leaders to i...        85000.0
# 595  Minimum 2 years of experience as a Business An...       154675.0
# 596  Extract data from various sources. Perform dat...       120000.0
# 597  Good understanding of Data Analysis and data m...       100000.0
# 598  5+ years’ experience in analysis, data managem...       174850.0
# 599  Working closely with key internal leaders to i...        85000.0
# 600  Minimum 2 years of experience as a Business An...       154675.0
# 601  Good understanding of Data Analysis and data m...       100000.0
# 602  5+ years’ experience in analysis, data managem...       174850.0
# 603  Strong R skills for data exploration purposes,...       215200.0
# 604  Working closely with key internal leaders to i...        85000.0
# 605  Minimum 2 years of experience as a Business An...       154675.0
# 606  Good understanding of Data Analysis and data m...       100000.0
# 607  5+ years’ experience in analysis, data managem...       174850.0
# 608  Strong R skills for data exploration purposes,...       215200.0
# 609  Fully experienced with SAP B1, Ecommerce and B...        90000.0
# 610  Good understanding of Data Analysis and data m...       100000.0
# 611  5+ years’ experience in analysis, data managem...       174850.0
# 612  International IT Manager, Global IT Manager. F...        90000.0
# 613  Solid SQL skill and be able analysis the data ...       100000.0
# 614  Demonstrated experience as Analyst with abilit...       174850.0
#
#      Job_Type
# 0           0
# 1           0
# 2           1
# 3           0
# 4           1
# 5           0
# 6           0
# 7           0
# 8           0
# 9           1
# 10          0
# 11          0
# 12          1
# 13          0
# 14          1
# 15          0
# 16          1
# 17          0
# 18          1
# 19          0
# 20          0
# 21          1
# 22          0
# 23          0
# 24          0
# 25          0
# 26          1
# 27          0
# 28          0
# 29          0
# ..        ...
# 585         1
# 586         1
# 587         0
# 588         1
# 589         0
# 590         1
# 591         0
# 592         1
# 593         1
# 594         0
# 595         1
# 596         1
# 597         0
# 598         1
# 599         0
# 600         1
# 601         0
# 602         1
# 603         1
# 604         0
# 605         1
# 606         0
# 607         1
# 608         1
# 609         0
# 610         0
# 611         1
# 612         0
# 613         0
# 614         1
#
# [615 rows x 6 columns]

# %%
# Scaling the data
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()
Xs = ss.fit_transform(X)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype uint8 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /anaconda3/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype uint8 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(Xs, y,random_state=50, test_size=0.3)

# %%
#using Logistic regression

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train, y_train)
lr.score(X_test, y_test)
# Out:
# 0.6054054054054054

# %%
#using decision tree to predict salary

# %%
dtc = DecisionTreeClassifier(max_depth=None, max_features='auto')
dtc.fit(X_train, y_train)
print(('dtc acc:', dtc.score(X_test, y_test)))
# Out:
# ('dtc acc:', 0.6054054054054054)

# %%
#Finding the feature Coefficients for Location

# %%
feature_importances = pd.DataFrame(dtc.feature_importances_,
                                   index = X.columns,
                                    columns=['importance'])
feature_importances.sort_values(by='importance', ascending=False).head(10)
# Out:
#                                       importance
# Canberra ACT                            0.168915
# Sydney Central Business District NSW    0.163540
# Sydney NSW                              0.111274
# Chatswood NSW                           0.087604
# Melbourne VIC                           0.063744
# Parramatta NSW                          0.058657
# Camperdown NSW                          0.056230
# Perth WA                                0.054510
# Newcastle NSW                           0.053190
# Brisbane QLD                            0.047554

# %% [markdown]
# ### Predict Salary by Summary using  Count Vectorizer

# %%
# NLP Using a count vectorizer to predict salary with summary as predictor  
from sklearn.feature_extraction.text import CountVectorizer

# %%
# Lets use the stop_words argument to remove words like "and, the, a"
cvec = CountVectorizer(stop_words='english',ngram_range=(3,3))

# Fit our vectorizer using our train data
cvec_model=cvec.fit(df_salary_new['Summary'])

# and check out the length of the vectorized data after
len(cvec.get_feature_names())
# Out:
# 2194

# %%
from sklearn.preprocessing import StandardScaler
#need to standardise as we calculate the distance

ss = StandardScaler()
Xs = ss.fit_transform(X)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /anaconda3/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
# Transforming our x data using our fit cvec.
# And converting the result to a DataFrame.
X = pd.DataFrame(cvec.transform(df_salary_new['Summary']).todense(),
                       columns=cvec.get_feature_names())
# setting the target variable
y= df_salary_new['Job_Type']

# %%
#X = pd.DataFrame(cvec.transform(df_salary_new['Summary']).todense(),columns=cvec.get_feature_names())

# %%
#saving the count vectorized summary to a dataframe
df_summmary= X
X.shape
# Out:
# (615, 2194)

# %%
# Which words appear the most?
word_counts = X.sum(axis=0)

word_counts.sort_values(ascending = False).head(20)
# Out:
# analysis data management       292
# data analysis data             203
# good understanding data        201
# able analysis data             200
# issue root cause               200
# analysis data issue            200
# create complex queries         200
# solid sql skill                200
# cause create complex           200
# skill able analysis            200
# root cause create              200
# sql skill able                 200
# data issue root                200
# understanding data analysis    200
# data management solid          188
# management solid sql           188
# experience analyst ability      92
# management reporting change     92
# reporting change management     92
# data management reporting       92
# dtype: int64

# %% [markdown]
# #### Model 1:Logistic Regression

# %%
#Import and fit our logistic regression 
from sklearn.linear_model import LogisticRegression
X_train, X_test, y_train, y_test = train_test_split(X, y,random_state=100, test_size=0.2)
lr = LogisticRegression()
model_summary=lr.fit(X_train, y_train)
y_pred= model_summary.predict(X_test)


print('Accuracy: ', metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy:  0.8699186991869918

# %%
# we can predict the salary label by 85.4% accuracy based on the the job summary

# %% [markdown]
# #### Model 2: Decision tree

# %%
dtc = DecisionTreeClassifier(max_depth=None, max_features=50)
dtc.fit(X_train, y_train)
print(('dtc acc:', dtc.score(X_test, y_test)))
# Out:
# ('dtc acc:', 0.8617886178861789)

# %%
feature_importances = pd.DataFrame(dtc.feature_importances_,
                                   index = X.columns,
                                    columns=['importance'])
feature_importances.sort_values(by='importance', ascending=False).head()
# Out:
#                                 importance
# data management reporting         0.311991
# business automotive data          0.127245
# issue root cause                  0.091642
# including data cleansing          0.041640
# validation reporting analytics    0.036040

# %% [markdown]
# ### Predict salary label with Job Title

# %%
# Setting the vectorizer just like we would set a model
cvec = CountVectorizer(stop_words='english',ngram_range=(3,3))

# Fitting the vectorizer on our training data
cvec.fit(df_salary_new['Job Title'])
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(3, 3), preprocessor=None, stop_words='english',
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
# Transforming our x_train data using our fit cvec.
# And converting the result to a DataFrame.
X = pd.DataFrame(cvec.transform(df_salary_new['Job Title']).todense(),
                       columns=cvec.get_feature_names())

# %%
#loading the features to a dataframe
df_jobtitle= X

X.shape
# Out:
# (615, 251)

# %%
# setting the target variable
y= df_salary_new['Job_Type']

# %%
from sklearn.preprocessing import StandardScaler
#need to standardise as we calculate the distance

ss = StandardScaler()
Xs = ss.fit_transform(X)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /anaconda3/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
#using test train split
X_train, X_test, y_train, y_test = train_test_split(Xs, y,random_state=80, test_size=0.2)

# %%
#Import and fit our logistic regression and test it too
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train, y_train)
lr.score(X_test, y_test)
# Out:
# 0.6178861788617886

# %%
word_counts = X.sum(axis=0)

word_counts.sort_values(ascending = False).head(20)
# Out:
# customer insights analyst         34
# datahub data analyst              29
# senior data analyst                6
# lead data scientist                6
# audience data analyst              5
# analyst digital media              5
# data analyst digital               5
# data analyst consultant            3
# analyst modeller visualisation     2
# data analyst modeller              2
# ict business analyst               2
# rural ehealth business             2
# 12 month contract                  2
# customer service systems           2
# service systems analyst            2
# junior business analyst            2
# contract fin services              2
# aps6 data analyst                  2
# data scientist python              2
# business systems analyst           2
# dtype: int64

# %%
dtc = DecisionTreeClassifier(max_depth=None, max_features='auto')
dtc.fit(X_train, y_train)
print(('dtc acc:', dtc.score(X_test, y_test)))
# Out:
# ('dtc acc:', 0.6666666666666666)

# %%
feature_importances = pd.DataFrame(dtc.feature_importances_,
                                   index = X.columns,
                                    columns=['importance'])
feature_importances.sort_values(by='importance', ascending=False).head()
# Out:
#                            importance
# customer insights analyst    0.104324
# datahub data analyst         0.099041
# senior data analyst          0.052983
# audience data analyst        0.021924
# aps6 data analyst            0.019790

# %% [markdown]
# ### Predicting Salary label with location, title and summary

# %%
X = pd.concat([df_summary,df_jobtitle, df_loc], axis=1)
y = df_salary_new.Job_Type

# %% [markdown]
# #### Model 1: Logistic Regression

# %%
#Import and fit our logistic regression and test it too
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train, y_train)
y_pred=lr.predict(X_test)
lr.score(X_test, y_test)
# Out:
# 0.6178861788617886

# %%
#print(classification_report(y_pred,y_test))
print(metrics.classification_report(y_test, y_pred, target_names=['lower salary', 'higher salary']))
# Out:
#                precision    recall  f1-score   support
#
#  lower salary       0.66      0.82      0.73        79
# higher salary       0.44      0.25      0.32        44
#
#     micro avg       0.62      0.62      0.62       123
#     macro avg       0.55      0.54      0.53       123
#  weighted avg       0.58      0.62      0.59       123

# %%
# Display confusion matrix
confusion = confusion_matrix(y_test, y_pred)
pd.DataFrame(confusion, columns=['Predicted Low Salary', 'Predicted High Salary'], 
             index=['Actual Low Salary', 'Actual High Salary'])
# Out:
#                     Predicted Low Salary  Predicted High Salary
# Actual Low Salary                     65                     14
# Actual High Salary                    33                     11

# %% [markdown]
# #### Model 2 : Random Forest Classifier

# %%
#using random forest to predict salary label

rfc = RandomForestClassifier(n_estimators=300, random_state=90)
rfc.fit(X_train, y_train)

rfc_pred = rfc.predict(X_test)
acc = accuracy_score(y_test, rfc_pred)
print ("Accuracy Score of Random Forest:", acc.round(3))
# Out:
# Accuracy Score of Random Forest: 0.667

# %% [markdown]
# #### Model 3: Decision tree classifier

# %%
dtc = DecisionTreeClassifier(max_depth=None, max_features=50)
dtc.fit(X_train, y_train)
print(('dtc acc:', dtc.score(X_test, y_test)))
# Out:
# ('dtc acc:', 0.6666666666666666)

# %% [markdown]
# # QUESTION 2: Factors that distinguish job category

# %%
# Second round of scraping done get Data scientist jobs

# %%
#loading the scraped Data scientist jobs
df = pd.read_csv('indeed_data_scientist.csv')

# %%
#Cleaning the data defined as a function 
def data_cleaning(df):
    


    df.drop('Unnamed: 0', axis=1,inplace=True)

    df_ds =df.dropna()

    df_ds=df_ds.reset_index()


    # Take commas,dollar sign and text'a year' out 
    df_ds['Salary'].replace(to_replace=['\$',',',' a year'], value='', inplace=True,regex=True)


    df_ds['new'] =df_ds['Salary'].str.extractall('(\d+)')[0].unstack().astype(float).mean(1)



    m1 = df_ds['Salary'].str.contains('month')
    m2 = df_ds['Salary'].str.contains('day')
    m3 = df_ds['Salary'].str.contains('hour')
    df_ds['Annual_salary'] =np.select([m1,m2,m3],[df_ds['new']*12,df_ds['new'] *365,df_ds['new']*8*365], default=df_ds['new'])

    df_ds=df_ds[['Company','Location','Annual_salary','Job Title','Summary']]

    df_ds.drop_duplicates(subset='Summary', inplace=True)
    df_ds.to_csv('indeed_data_scientist_cleaned.csv', encoding='utf-8')

    df_ds = pd.read_csv('indeed_data_scientist_cleaned.csv')
    return df_ds

# %%
#calling the function to clean the data
df_ds= data_cleaning(df)

# %%
df_ds.drop('Unnamed: 0',axis=1,inplace=True)

# %%
#combine data scientist and data analyst jobs
df_full=pd.concat([df_salary_new,df_ds],axis=0)

# %%
# deleting the duplicate rows based on summary
df_ds.drop_duplicates(subset='Summary', inplace=True)

# %%
df_full['Job_Type'] = [1 if x > median else 0 for x in df_full.Annual_salary]

# %%
df_full.shape
# Out:
# (740, 6)

# %% [markdown]
# ## Distinguish data scientists from other data jobs

# %%
# Creating label for Data scientist Jobs
df_full['Data_Scientist']= df_full['Job Title'].apply(lambda x: 1 if x in ['Data Scientist','Data Scientists','DATA SCIENTIST'] else 0)

# %%
#SetTing the target variable
y=df_full['Data_Scientist']

# %%
#calculating the baseline accuracy
1 - sum(y) / len(y)
# Out:
# 0.9797297297297297

# %%
#count vectorizer 
cvec = CountVectorizer(ngram_range=(2,2),stop_words='english',max_features=50)

# Fitting the vectorizer on our training data
cvec.fit(df_full['Summary'])
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=50, min_df=1,
#         ngram_range=(2, 2), preprocessor=None, stop_words='english',
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
X = pd.DataFrame(cvec.transform(df_full['Summary']).todense(),columns=cvec.get_feature_names())

# %%
len(df_full['Annual_salary'])
# Out:
# 740

# %% [markdown]
# ### Using k means clustering

# %%
from sklearn.preprocessing import scale
from sklearn.cluster import KMeans, k_means
from sklearn import cluster, metrics


df_loc=pd.get_dummies(df_full['Location'], drop_first=True)
df_jobtitle= pd.DataFrame(cvec.transform(df_full['Job Title']).todense(),
                       columns=cvec.get_feature_names())
# Transforming our x data using our fit cvec.
# And converting the result to a DataFrame.
df_summary = pd.DataFrame(cvec.transform(df_full['Summary']).todense(),
                       columns=cvec.get_feature_names())

# using the features SummAry and Job Title for clustering
X= pd.concat([df_summary,df_jobtitle],axis=1)



#X = pd.DataFrame(cvec.transform(df_full['Summary']).todense(),columns=cvec.get_feature_names())
kmeans = cluster.KMeans(n_clusters=2)
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
labels = kmeans.labels_
centroids = kmeans.cluster_centers_
df_full['Labels']= labels

# %%
from sklearn.metrics import completeness_score, homogeneity_score, v_measure_score, adjusted_mutual_info_score

# %%
print(completeness_score(df_full['Data_Scientist'], labels))
# Out:
# 0.011077642644507214

# %%
metrics.silhouette_score(X, labels, metric='euclidean')
# Out:
# 0.6318572180387948

# %%
#The score is high (close to 1), indicating that there is pretty good separation
# and coherence with 2 clusters.

# %%
print(homogeneity_score(df_full['Data_Scientist'], labels))
# Out:
# 0.06523531566445571

# %%
print(adjusted_mutual_info_score(df_full['Data_Scientist'], labels))
# Out:
# 0.009861754973659966

# %% [markdown]
# ## Categorizing Senior and Junior jobs

# %%
y = [1 if 'Senior' in x else 0 for x in df_full['Job Title'].values]

# %%
# Calculate the baseline.
1 - sum(y) / len(y)
# Out:
# 0.9648648648648649

# %%
df_company= pd.get_dummies(df_full['Company'],drop_first=True)

# %%
vect = TfidfVectorizer(stop_words='english', min_df=0.005, ngram_range=(2,3))
X_sum = vect.fit_transform(df_full['Summary'])
df_sum = pd.DataFrame(X_sum.toarray(), columns=vect.get_feature_names())

# %%
X= pd.concat([df_sum,df_jobtitle], axis=1)
X.columns
# Out:
# Index(['ability years', 'ability years experience', 'able analysis',
#        'able analysis data', 'advanced excel', 'analyse data', 'analysis data',
#        'analysis data issue', 'analysis data management', 'analysis reporting',
#        ...
#        'roadmap standardizes', 'root cause', 'skill able', 'solid sql',
#        'sql skill', 'stakeholder engagement', 'standardizes optimizes',
#        'understanding data', 'working closely', 'years experience'],
#       dtype='object', length=427)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %% [markdown]
# ### Model 1: Logistic Regression

# %%
lr = LogisticRegression(solver='lbfgs', max_iter=200)
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)

# %%
print(metrics.confusion_matrix(y_test, y_pred))
print('-'*55, '\n')
print(metrics.classification_report(y_test, y_pred, target_names=['junior', 'senior']))
# Out:
# [[144   0]
#  [  4   0]]
# -------------------------------------------------------
#
#               precision    recall  f1-score   support
#
#       junior       0.97      1.00      0.99       144
#       senior       0.00      0.00      0.00         4
#
#    micro avg       0.97      0.97      0.97       148
#    macro avg       0.49      0.50      0.49       148
# weighted avg       0.95      0.97      0.96       148
# /anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### Model 2: Random Forest Classifier

# %%
rfc = RandomForestClassifier(n_estimators=200, random_state=1)
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=None,
#             oob_score=False, random_state=1, verbose=0, warm_start=False)

# %%
rfc_pred = rfc.predict(X_test)
acc = accuracy_score(y_test, rfc_pred)
print ("Accuracy Score of Random Forest:", acc.round(3))
# Out:
# Accuracy Score of Random Forest: 0.98

# %%
# Check important features.
pd.Series(clf.feature_importances_, index=X_train.columns).sort_values(ascending=False)[:40]
# Out:
# senior analyst                   0.150029
# senior data                      0.118573
# senior data analyst              0.077881
# data scientists                  0.062069
# skills including                 0.048462
# data models                      0.044454
# analyst join                     0.043583
# senior data scientist            0.040628
# data analyst                     0.037932
# data manipulation                0.030246
# analyse data                     0.027479
# data analyst                     0.024803
# years experience                 0.019229
# working closely                  0.015417
# data reporting                   0.015414
# work closely                     0.015182
# data scientist                   0.015072
# analyst responsible              0.014152
# data management                  0.012288
# data science                     0.010798
# machine learning                 0.010571
# data analyst data                0.009514
# big data                         0.007692
# exciting opportunity             0.006446
# method development               0.006177
# experience data                  0.005416
# skills required                  0.005329
# prior looking                    0.005083
# data scientist                   0.004939
# data analytics                   0.004758
# efficient problem                0.004587
# method development scientist     0.004104
# data interpretation              0.003924
# problem solving                  0.003838
# problem solving scientific       0.003811
# client leading                   0.003585
# business analyst                 0.003582
# analyst data                     0.003465
# data interpretation abilities    0.003400
# solving scientific               0.003393
# dtype: float64
